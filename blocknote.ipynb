# %% [markdown]
# ✔️ ✅ ☐ 🔲 🔨 ⁉ ❓ ❔ ⁇ ℹ️

# %%
REM Додавання PATH to OSGeo4W Shell
set PATH=%PATH%;D:\Program Files\Git\cmd

# %%
REM Ініціалізація сайту xml_ua_docs
REM новий публічний репозитарій xml_ua_docs на github:
REM Скопіювати URL_репозитарію
REM OSGeo4W Shell:
cd D:\work\xml_ua_docs
git clone <URL_репозиторію>
cd xml_ua_docs
move path\to\plugins\xml_ua\docs D:\work\xml_ua_docs
move path\to\plugins\xml_ua\mkdocs.yml D:\work\xml_ua_docs
REM D:\work\xml_ua_docs\mkdocs.yml: site_name
REM site_url: https://<your-username>.github.io/xml_ua-docs/
mkdocs serve
REM http://127.0.0.1:8000/
pip install ghp-import
mkdocs build
ghp-import -n -p -f site
git add .
git commit -m "Initial commit of documentation"
git push origin main

# %%
REM коміт і публікація змін у xml_ua_docs
mkdocs build
ghp-import -n -p -f site
git add .
git commit -m "Update documentation"
git push origin main
